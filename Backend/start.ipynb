# %%
# %pip install -U pandas
# Out:
# ...
#   Using cached numpy-2.5.2-cp313-cp313-win_amd64.whl.metadata (6.6 kB)
# ...
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.8 MB ? eta -:--:--
#    ----- ---------------------------------- 1.3/9.8 MB 6.6 MB/s eta 0:00:02
#    -------------- ------------------------- 3.7/9.8 MB 7.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.5/9.8 MB 7.9 MB/s eta 0:00:01
#    -------------------------------- ------- 7.9/9.8 MB 8.6 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.8 MB 8.8 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 8.6 MB/s eta 0:00:00
# Using cached numpy-2.5.2-cp313-cp313-win_amd64.whl (12.5 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
df = pd.read_csv("data/lab_test_results_public.csv")

# %%
df.head()
# Out:
#          Date                     Test_Name Result   Unit Reference_Range  \
# 0  2025-08-12                      Ferritin   28.9   ug/L          15-150
# 1  2025-08-12  Glikozile Hemoglobin (HbA1c)    5.0      %         4.0-6.0
# 2  2025-08-12                     Total IgE   1.73   KU/L         0.1-100
# 3  2025-08-12                       İnsülin   9.42   mU/L        2.6-24.9
# 4  2025-08-12                    Serbest T4   1.14  ng/dL       0.87-1.70
#
#    Status                               Comment  Min_Reference  Max_Reference  \
# 0  Normal      Demir depoları alt-orta seviyede          15.00          150.0
# 1  Normal  Kan şekeri uzun dönem ortalaması iyi           4.00            6.0
# 2  Normal                    Alerji riski düşük           0.10          100.0
# 3  Normal                        İnsülin normal           2.60           24.9
# 4  Normal              Tiroid fonksiyonu normal           0.87            1.7
#
# ...

# %%
df.shape
# Out:
# (27, 11)

# %%
print("Shape:", df.shape)
print("\nColumns:")
print(df.columns.tolist())

print("\nData types:")
print(df.dtypes)

print("\nMissing values:")
print(df.isna().sum())
# Out:
# Shape: (27, 11)
#
# Columns:
# ['Date', 'Test_Name', 'Result', 'Unit', 'Reference_Range', 'Status', 'Comment', 'Min_Reference', 'Max_Reference', 'Unit_Description', 'Recommended_Followup']
#
# Data types:
# Date                        str
# Test_Name                   str
# Result                      str
# Unit                        str
# Reference_Range             str
# Status                      str
# Comment                     str
# Min_Reference           float64
# Max_Reference           float64
# Unit_Description            str
# Recommended_Followup        str
# dtype: object
#
# Missing values:
# Date                    0
# Test_Name               0
# Result                  0
# Unit                    0
# Reference_Range         0
# Status                  0
# Comment                 0
# Min_Reference           8
# Max_Reference           8
# Unit_Description        0
# Recommended_Followup    0
# dtype: int64
